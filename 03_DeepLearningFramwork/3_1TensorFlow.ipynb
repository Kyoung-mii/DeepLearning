# %% [markdown]
# <a href="https://colab.research.google.com/github/Kyoung-mii/DeepLearning/blob/main/03_DeepLearningFramwork/3_1TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3-1 [1] 지연 실행 모드의 계산 그래프 구성

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# 계산 그래프 정의
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)
c = a + b
print('c=', c)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# c= Tensor("add:0", dtype=float32)

# %% [markdown]
# # 3-1 [2] 계산 그래프의 실행

# %%
# 세션을 생성하여 그래프를 실행함
with tf.Session() as sess:
    # 'c'의 연산을 하는 그래프를 실행함
    result = sess.run(c, {a:2., b:3.})
print('result = ', result)
# Out:
# result =  5.0

# %% [markdown]
# # 3-2 [1] 즉시 실행 모드의 프로그램

# %%
import tensorflow as tf

a = tf.constant(2.)
b = tf.constant(3.)
c = a + b
print('c = ', c)
# Out:
# c =  Tensor("add_1:0", shape=(), dtype=float32)
